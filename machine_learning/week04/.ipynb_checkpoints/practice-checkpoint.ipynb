# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

iris = pd.read_csv("./iris-3.csv")
dataset = np.array(iris)

# split data, target
data = dataset[:, 0:4]
target = dataset[:, 4]
print(dataset)

# train_test_split
x_train, y_train, x_test, y_test = train_test_split(data, target, random_state=0)

# 클래스 객체 생성
tree = DecisionTreeClassifier(max_depth = 3, random_state = 0)
# Out:
# [[5.1 3.5 1.4 0.2 1. ]
#  [4.9 3.  1.4 0.2 1. ]
#  [4.7 3.2 1.3 0.2 1. ]
#  [4.6 3.1 1.5 0.2 1. ]
#  [5.  3.6 1.4 0.2 1. ]
#  [5.4 3.9 1.7 0.4 1. ]
#  [4.6 3.4 1.4 0.3 1. ]
#  [5.  3.4 1.5 0.2 1. ]
#  [4.4 2.9 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.4 3.7 1.5 0.2 1. ]
#  [4.8 3.4 1.6 0.2 1. ]
#  [4.8 3.  1.4 0.1 1. ]
#  [4.3 3.  1.1 0.1 1. ]
#  [5.8 4.  1.2 0.2 1. ]
#  [5.7 4.4 1.5 0.4 1. ]
#  [5.4 3.9 1.3 0.4 1. ]
#  [5.1 3.5 1.4 0.3 1. ]
#  [5.7 3.8 1.7 0.3 1. ]
#  [5.1 3.8 1.5 0.3 1. ]
#  [5.4 3.4 1.7 0.2 1. ]
#  [5.1 3.7 1.5 0.4 1. ]
#  [4.6 3.6 1.  0.2 1. ]
#  [5.1 3.3 1.7 0.5 1. ]
#  [4.8 3.4 1.9 0.2 1. ]
#  [5.  3.  1.6 0.2 1. ]
#  [5.  3.4 1.6 0.4 1. ]
#  [5.2 3.5 1.5 0.2 1. ]
#  [5.2 3.4 1.4 0.2 1. ]
#  [4.7 3.2 1.6 0.2 1. ]
#  [4.8 3.1 1.6 0.2 1. ]
#  [5.4 3.4 1.5 0.4 1. ]
#  [5.2 4.1 1.5 0.1 1. ]
#  [5.5 4.2 1.4 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [5.  3.2 1.2 0.2 1. ]
#  [5.5 3.5 1.3 0.2 1. ]
#  [4.9 3.1 1.5 0.1 1. ]
#  [4.4 3.  1.3 0.2 1. ]
#  [5.1 3.4 1.5 0.2 1. ]
# ...

# %%
print(x_train.size)
print(x_test.size)
print(y_train.size)
print(y_test.size)
# Out:
# 440
# 148
# 110
# 37

# %%
# 모델 생성
# x_train : 훈련데이터 numpy 배열
# y_train : 훈련데이터 레이블
tree.fit(x_train, y_train)

# 테스트 데이터에 대해 클래스 레이블 예측
# x_test : 테스트데이터 numpy 배열
# y_test : 테스트데이터 레이블
y_pred = tree.predict(x_test)
print("테스트 셑의 정확도: {:.2f}".format(np.mean(y_pred==y_test)))
# Out:
# 테스트 셑의 정확도: 1.00

# %%
# graphviz
import graphviz
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file="tree.dot")

with open("tree.dot") as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_443777/888436857.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(10,7)) # 렌더링 크기 설정.
# ----> 5 plot_tree(tree, max_depth=3, filled=True, feature_names=['1.', '2.', '3.'])
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     193         fontsize=fontsize,
#     194     )
# --> 195     return exporter.export(decision_tree, ax=ax)
#     196
#     197
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     654         ax.clear()
#     655         ax.set_axis_off()
# --> 656         my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
# ...
