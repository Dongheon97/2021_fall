# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

iris = pd.read_csv("./iris-3.csv")
dataset = np.array(iris)

# split data, target
data = dataset[:, 0:4]
target = dataset[:, 4]

# train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, target, random_state=0)

# 클래스 객체 생성
tree = DecisionTreeClassifier(max_depth = 3, random_state = 0)

# %%
# 모델 생성
# x_train : 훈련데이터 numpy 배열
# y_train : 훈련데이터 레이블
tree.fit(x_train, y_train)

# 테스트 데이터에 대해 클래스 레이블 예측
# x_test : 테스트데이터 numpy 배열
# y_test : 테스트데이터 레이블
y_pred = tree.predict(x_test)
print("테스트 셑의 정확도: {:.2f}".format(np.mean(y_pred==y_test)))
# Out:
# 테스트 셑의 정확도: 1.00

# %%
import graphviz
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file="tree.dot")

with open("tree.dot") as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
iris_3 = pd.read_csv("./iris+3.csv", header=None)
data_3 = np.array(iris_3)
print(data)

tree.fit(x_train, data_3)
pred = tree.predict(x_test)
# Out:
# [['feature1' 'feature2' 'feature3' 'feature4']
#  ['4.4' '3.2' '1.3' '0.2']
#  ['6.1' '2.9' '4.7' '1.4']
#  ['7.2' '3.6' '6.1' '2.5']]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_202002/1696603174.py in <module>
#       6 data_3 = dataset_3[:, 0:4]
#       7
# ----> 8 tree.fit(x_train, data_3)
#       9 pred = tree.predict(x_test)
#      10
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     297
#     298         if len(y) != n_samples:
# --> 299             raise ValueError(
# ...
